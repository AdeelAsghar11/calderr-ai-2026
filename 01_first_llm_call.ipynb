# %% [markdown]
# # First LLM Call
# Testing Groq API with LangChain LCEL chain.

# %%
import os
from dotenv import load_dotenv
from langchain_groq import ChatGroq
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

load_dotenv()
# Out:
# True

# %% [markdown]
# ## Build the Chain
# prompt → model → output parser

# %%
llm = ChatGroq(model="llama-3.3-70b-versatile", temperature=0.7, api_key=os.getenv("GROQ_API_KEY"))
prompt = ChatPromptTemplate.from_messages([
    ("system", "You are a helpful AI engineering assistant."),
    ("user", "{question}")
])
chain = prompt | llm | StrOutputParser()

# %%
response = chain.invoke({"question": "What is an AI agent and why does it matter?"})
print(response)
# Out:
# An AI agent is a program or system that uses artificial intelligence (AI) to perform tasks, make decisions, and interact with its environment. It is designed to perceive its surroundings, reason about the current state, and take actions to achieve specific goals. AI agents can be simple or complex, ranging from basic chatbots to sophisticated autonomous systems.
#
# There are several types of AI agents, including:
#
# 1. **Simple Reflex Agents**: React to the current state of the environment without considering future consequences.
# 2. **Model-Based Reflex Agents**: Maintain an internal model of the environment and use it to make decisions.
# 3. **Goal-Based Agents**: Have specific goals and use planning to achieve them.
# 4. **Utility-Based Agents**: Make decisions based on a utility function that estimates the desirability of each action.
#
# AI agents matter for several reasons:
#
# 1. **Automation**: AI agents can automate repetitive, mundane, or dangerous tasks, freeing humans to focus on more complex and creative work.
# 2. **Decision-Making**: AI agents can analyze vast amounts of data, identify patterns, and make informed decisions, often faster and more accurately than humans.
# 3. **Personalization**: AI agents can learn individual preferences and tailor their behavior to provide personalized experiences.
# 4. **Efficiency**: AI agents can optimize processes, reduce waste, and improve overall efficiency in various industries, such as manufacturing, logistics, and healthcare.
# 5. **Innovation**: AI agents can drive innovation by exploring new possibilities, identifying opportunities, and developing novel solutions.
#
# Applications of AI agents can be seen in:
#
# 1. **Virtual Assistants**: Siri, Alexa, and Google Assistant use AI agents to understand voice commands and perform tasks.
# 2. **Autonomous Vehicles**: Self-driving cars rely on AI agents to perceive their environment, make decisions, and navigate.
# 3. **Customer Service**: Chatbots and virtual customer support agents use AI to provide 24/7 support and resolve issues.
# 4. **Smart Homes**: AI agents can control and optimize home automation systems, such as lighting, temperature, and security.
# 5. **Healthcare**: AI agents can help diagnose diseases, develop personalized treatment plans, and monitor patient progress.
#
# In summary, AI agents have the potential to revolutionize various aspects of our lives, from automation and decision-making to personalization and innovation. As AI technology continues to evolve, we can expect to see more sophisticated and widespread applications of AI agents.
