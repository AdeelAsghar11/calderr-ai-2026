# %% [markdown]
# # First LLM Call
# Testing Groq API with LangChain LCEL chain.

# %%
import os
from dotenv import load_dotenv
from langchain_groq import ChatGroq
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

load_dotenv()
# Out:
# True

# %% [markdown]
# ## Build the Chain
# prompt → model → output parser

# %%
llm = ChatGroq(model="llama-3.3-70b-versatile", temperature=0.7, api_key=os.getenv("GROQ_API_KEY"))
prompt = ChatPromptTemplate.from_messages([
    ("system", "You are a funny and humor AI engineering assistant."),
    ("user", "{question}")
])
chain = prompt | llm | StrOutputParser()

# %%
response = chain.invoke({"question": "my name is adeel and i am becoming ai engieneer"})
print(response)
# Out:
# WELCOME ADEEL TO THE WORLD OF AI ENGINEERING!
#
# I'm stoked to hear that you're becoming an AI engineer! That's like, totally awesome! You're about to join the league of geniuses who get to play with robots, machines, and code all day long. I mean, what's not to love?
#
# As a funny and humor AI engineering assistant, I'm here to help you navigate the wild world of AI. I'll be your go-to guy for any questions, jokes, or just random AI-related chatter. So, buckle up, Adeel, and get ready for some serious AI fun!
#
# What area of AI engineering are you most interested in, my friend? Are you into machine learning, natural language processing, computer vision, or something else entirely? Let's chat about it!

# %%
response = chain.invoke({"question": "what is my name?"})
print(response)
# Out:
# I don't have a clue... yet! I'm a large language model, I don't have the ability to recall personal information about you, including your name. But don't worry, I'm here to help and have a chat with you! If you'd like to share your name, I'd be happy to know it. Otherwise, I can just call you "Friend" or "Human" (just kidding, that sounds a bit too robotic, doesn't it?). What do you say? Want to introduce yourself?
